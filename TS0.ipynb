# %% [raw]
# TS0: Primeros pasos en la simulación

# %% [raw]
# El siguiente script genera una señal senoidal, la muestrea con una frecuencia de muestreo de 1000 Hz y grafica N muestras. Con el fin de ver que relacion de la frecuencia de Nyquist con la frecuencia de la señal a muestrear se generaron señales de distinta frecuencia.

# %%
import matplotlib.pyplot as plt
import numpy as np

fs = 1000   #frecuencia de muestreo
N = 1000    #cantidad de muestras

def func_sen(vmax, dc, ff, ph, nn, fs):

    xx = vmax*np.sin(2*np.pi*ff*nn/fs + 2*np.pi*ph) + dc
    tt = nn/fs
    
    return(tt, xx)


vmax = 1                #amplitud
dc = 0                  #offset
ff = 1                  #frecuencia de señal
ph = 0                  #fase
nn = np.arange(0, N)    #vector de muestras

tt, xx = func_sen(vmax, dc, ff, ph, nn, fs)

plt.plot(tt, xx)
plt.title(ff)
plt.xlabel('tiempo [ms]')
plt.ylabel('Amplitud [V]')

# %% [markdown]
# ![ff sen 1 Hz.png](attachment:a642ed17-9b4f-45e5-8feb-946928cd3845.png)
# ![ff sen 1001 Hz.png](attachment:b6997e31-495c-4ff8-9b3c-2a048563da46.png)![ff sen 2001 Hz.png](attachment:3aa380b9-7f87-4830-b0ab-3f63b6a8097e.png)![ff sen 500 Hz.png](attachment:3002280d-b870-42b3-9643-423c31126913.png)![ff sen 999 Hz.png](attachment:7e7762e5-5bf7-489e-9cf3-ee7146d5062b.png)
